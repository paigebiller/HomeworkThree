# %% [markdown]
# # Homework Three
#
# **Goal:**
#
# Given an iris flower's *petal length*, *petal width*, *sepal length*, and *sepal width*, what **variable(s)** should we look at if we wanted to **predict the species** of the flower?

# %% [markdown]
# **Step 0**: Baseline image embedding code.

# %%
import pandas as pd
from pandas.tools.plotting import scatter_matrix
# %matplotlib inline

# %% [markdown]
# **Step 1**: Read iris.txt into a data frame
#
# **Commentary**:
#
# 1) Treating the iris text file as a csv file, we read the file in as a pandas dataframe.
#
# 2) Using the csv parser, we indicate that the variables for each row are separated by commas.
#
# 3) We use the first row as the header/column names (header=0).
#
# 4) Then, using the *names* option, we add spacing inside multi-word column names (Sepal Length instead of SepalLength, etc).

# %%
irisdata = pd.read_csv('C:/Users/paigebiller/Documents/GitHub/HomeworkThree/iris.txt',\
                   sep=",", header = 0, names = ['Sepal Length','Sepal Width','Petal Length','Petal Width','Species'])
irisdata
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width         Species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %% [markdown]
# **Step 1 Observations**:
#
# The print statement displays a leading observation number column, 4 numeric decimal columns, and one text Species column
#
# 150 rows and 5 columns in total. can compare to expectations to ensure the irisdata dataframe was created successfully.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Explore the data
#
# **Step 2**: Print the head the dataset
#
# **Commentary**:
#
# 1) As a second step, we print the **head** of our pandas dataframe, irisdata
#
# 2) The default print of head is ***5 rows***, but we can pass a custom count of rows in the parentheses of the argument
#
# 3) Because there are 150 rows total, I am choosing to print roughly the first 10% of the observations (15 rows)
#
# This process can help us explore the magnitude, data types, and values of our data

# %%
irisdata.head(15)
# Out:
#     Sepal Length  Sepal Width  Petal Length  Petal Width      Species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %% [markdown]
# **Step 2 Observations**:
#
# The first 4 columns are fairly small, decimal numbers and the fifth column in a text value for Species, including a hyphen character.
#
# Each of the first 15 observations are Species Iris-setosa.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Step 3**: Print the tail the dataset
#
# **Commentary**:
#
# 1) As a third step, we print the **tail** of our pandas dataframe, irisdata
#
# 2) The default print of head is ***5 rows***, just like head, but we can pass a custom count of rows in the parentheses of the argument
#
# 3) Because there are 150 rows total, I am choosing to print roughly the last 10% of the observations (15 rows)
#
# This process can help us explore the magnitude, data types, and values of our data

# %%
irisdata.tail(15)
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width         Species
# 135           7.7          3.0           6.1          2.3  Iris-virginica
# 136           6.3          3.4           5.6          2.4  Iris-virginica
# 137           6.4          3.1           5.5          1.8  Iris-virginica
# 138           6.0          3.0           4.8          1.8  Iris-virginica
# 139           6.9          3.1           5.4          2.1  Iris-virginica
# 140           6.7          3.1           5.6          2.4  Iris-virginica
# 141           6.9          3.1           5.1          2.3  Iris-virginica
# 142           5.8          2.7           5.1          1.9  Iris-virginica
# 143           6.8          3.2           5.9          2.3  Iris-virginica
# 144           6.7          3.3           5.7          2.5  Iris-virginica
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# ...

# %% [markdown]
# **Step 3 Observations**:
#
# While the first 10% of observations in the irisdata dataframe were species Iris-setosa, the tail/last 10% are Iris-virginica.
#
# This suggests that the file may be sorted by species and contains at least two species values in total.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Step 4: Print summary statistics for the data frame (both numeric and categorical columns) **
#
# **Commentary**:
#
# 1) We can use the built in .describe() function to display summary statistics for each variable in irisdata
#
# 2) Specifying (include=['object'] prints summary statistics for categorical variables (Species, in this case) including:
#
#     *total observations with non-missing values for the variable
#     *the number of unique values of the variable
#     *the most-commonly occurring value, and
#     *the frequency of that most common value in the dataset
#
# **Note**: if multiple values have the same frequency, the top value is chosen arbitrarily (as in this dataset, with 3 values x 50 observations)
#
# 2) Specifying (include=['object'] prints summary statistics for numeric variables (Sepal Length, Sepal Width, Petal Length, and Petal Width) including:
#
#     *count
#     *mean
#     *standard deviation
#     *min
#     *max, and
#     *lower, 50, and upper percentiles
#
# **Note**: we can also use describe(include='all') to print both the numeric and categorical columns in one table.
#
# Because the descriptor variables are not compatible (unique, top, and freq apply to categorical variables only, not numeric), I prefer the printout less than the versions including object and number variables separately.
#
# I have included this option at the end for completeness.

# %%
irisdata.describe(include=['object']) #categorical variables only
# Out:
#                 Species
# count               150
# unique                3
# top     Iris-versicolor
# freq                 50

# %%
irisdata.describe(include=['number']) #numeric variables only
# Out:
#        Sepal Length  Sepal Width  Petal Length  Petal Width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
irisdata.describe(include='all') #both categorical and numeric variables
# Out:
#         Sepal Length  Sepal Width  Petal Length  Petal Width          Species
# count     150.000000   150.000000    150.000000   150.000000              150
# unique           NaN          NaN           NaN          NaN                3
# top              NaN          NaN           NaN          NaN  Iris-versicolor
# freq             NaN          NaN           NaN          NaN               50
# mean        5.843333     3.054000      3.758667     1.198667              NaN
# std         0.828066     0.433594      1.764420     0.763161              NaN
# min         4.300000     2.000000      1.000000     0.100000              NaN
# 25%         5.100000     2.800000      1.600000     0.300000              NaN
# 50%         5.800000     3.000000      4.350000     1.300000              NaN
# 75%         6.400000     3.300000      5.100000     1.800000              NaN
# max         7.900000     4.400000      6.900000     2.500000              NaN

# %% [markdown]
# **Step 4 Observations**:
#
# The summary statistics show that:
#
#     There are 3 categories for species
#
#     The average for Sepal Width and Petal Length is similar, but Petal Length has a wider range
#
#     Sepal Length, Sepal Width, and Petal Width appear normally distributed, with similar mean and median

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Step 5: Generate a box plot for the data set **
#
# **Commentary**:
#
# 1) On the object irisdata (a dataframe), we can call the method plot, and then call the box specification
#
# 2) Box plots help us view 5 summary statistics for each numeric variable:
#
#     *minimum
#     *first quartile
#     *median
#     *third quartile
#     *maximum
#
# I have used the ggplot style to make the output more polished-looking

# %%
import matplotlib
matplotlib.style.use('ggplot')
irisdata.plot.box()

# %% [markdown]
# **Step 5 Observations**:
#
# The box plot gives us a feel for the distribution of each variable
#
# Petal Length has the highest range, with uneven balance of the median within the IQR
#
# Sepal Width has the tightest distribution across all the observations, so it is most likely a weak predictor of Species overall

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Step 6: Generate a line plot for the data set **
#
# **Commentary**:
#
# 1) On the object irisdata (a dataframe), we can call the method plot, which produces a line graph by default
#
# 2) Subplots=True helps us by separating each variable into a separate, easier to read graph
#
# The ggplot style continues through this section because of the successive setup of jupyer notebooks

# %%
irisdata.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000000192594E0>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000001932B4A8>], dtype=object)

# %% [markdown]
# **Step 6 Observations**:
#
# We can see from the line graphs that Petal Length and Petal Width move in step with each other, with a direct positive relationship.
#
# We know the data is sorted by species, and we can see step-wise jumps in both variables for each 50 observations, so these variables appear most promising to use to predict the species.
#
# Sepal width seems fairly inconsistent, with Sepal Length showing a slightly positive relationship from left to right

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Step 7: Generate a histogram of the data set **
#
# **Commentary**:
#
# 1) On the object irisdata (a dataframe), we can call the method plot, then call the histogram specification
#
# 2) We specify an alpha and a bin count to print each histogram separately instead of overlayed on each other
#
# The ggplot style continues through this section because of the successive setup of jupyer notebooks

# %%
irisdata.hist(alpha=0.5, bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000018078B00>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000197AFFD0>]], dtype=object)

# %% [markdown]
# **Step 7 Observations**:
#
# The histograms underscore some of our earlier observations, with Sepal Width looking the most tight and normally distributed, and Petal Length and Width skipping entire buckets and having less smooth distributions.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Group the data on the Species column and explore the partitioned dataset
#
# **Step 8**: Print the summary statistics for each species in the dataset
#
# **Commentary**:
#
# 1) We use the groupby method to group the irisdata dataframe by the 3 distinct values for Species
#
# 2) Using the describe method prints the summary statistics for each of the 4 numeric variables (Petal Length, Petal Width, Sepal Length, and Sepal Width) like we had before for the total dataset

# %%
irisdata.groupby('Species').describe() #don't need to specify include in describe because all other vars are numeric
# Out:
#                        Petal Length  Petal Width  Sepal Length  Sepal Width
# Species
# Iris-setosa     count     50.000000    50.000000     50.000000    50.000000
#                 mean       1.464000     0.244000      5.006000     3.418000
#                 std        0.173511     0.107210      0.352490     0.381024
#                 min        1.000000     0.100000      4.300000     2.300000
#                 25%        1.400000     0.200000      4.800000     3.125000
#                 50%        1.500000     0.200000      5.000000     3.400000
#                 75%        1.575000     0.300000      5.200000     3.675000
#                 max        1.900000     0.600000      5.800000     4.400000
# Iris-versicolor count     50.000000    50.000000     50.000000    50.000000
#                 mean       4.260000     1.326000      5.936000     2.770000
#                 std        0.469911     0.197753      0.516171     0.313798
# ...

# %% [markdown]
# **Step 8 Observations**:
#
# This output confirms there are 50 observations per species type.
#
# The average value for Petal Length is the most different for each species, lowest for Iris-setosa and highest for Iris-virginica.
#
# Petal Width and Sepal Length also follow this pattern, lowest for Iris-setosa and highest for Iris-virginica.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Step 9**: Generate a boxplot for each species in the dataset
#
# **Commentary**:
#
# 1) We can use the by option in the boxplot method to group the data by Species
#
# 2) The figsize option lets us set a width and length to space out the plots to make it easier to read

# %%
irisdata.boxplot(by='Species',figsize=(10,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000019812438>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000000199DF320>]], dtype=object)

# %% [markdown]
# **Step 9 Observations**:
#
# Petal Length is the most differentiated across species
#
# Sepal Length and Petal Width continue to show a left-to-right direct, positive relationship
#
# Sepal Width is the least differentiated across the three series values

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# **Step 10**: Generate a scatter matrix for the dataset
#
# **Commentary**:
#
# 1) We call the scatter_matrix method on our irisdata dataframe, and specify the figsize to make the results fit the screen better
#
# The scatter matrix contains plots of each variable against the other variables, which can help us decipher relationships and interaction patterns

# %%
scatter_matrix(irisdata, figsize=(10,8))

# %% [markdown]
# **Step 10 Observations**:
#
# The strongest interactions are between Petal Length and Petal Width, and Petal Length and Sepal Length.
#
# Some of the other combinations display more of a shotgun, randomized pattern.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Group the data on the Species column and explore the partitioned dataset
#
# **Step 11**: Provide an answer to the analysis question based on your interpretation of the data
#
# Overall, Petal Length and Petal Width appear to be the best predictors of Species.
#
# In the boxplots grouped by Species, we see that the values for these variables are fairly differentiated by Species, with little overlap.
#
# They also have the strongest interaction relationship in the scatterplot matrix. We expect this based on the pre-grouped line plots, which show the variable values moving in step with each other as we step from observation 1 to 150 (left to right).
#
# Knowing the Petal Length and/or Petal Width, we can likely identify the Species with more accuracy than if we knew the values for Sepal Length or Sepal Width, which are more normally distributed and less distinct by Species.
